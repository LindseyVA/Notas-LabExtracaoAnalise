# %%
import pandas as pd



url = 'https://en.wikipedia.org/wiki/Chamber_of_Deputies_(Brazil)'

tabela = pd.read_html(url) # Uma lista com vários itens
tabela
# Out:
# [             Chamber of Deputies Câmara dos Deputados  \
#  0           57th Legislature of the National Congress
#  1                                                 NaN
#  2                                                Type
#  3                                                Type
#  4                                         Term limits
#  5                                             History
#  6                                             Founded
#  7                                 New session started
#  8                                          Leadership
#  9                                           President
#  10                                  Government Leader
#  11                                    Majority Leader
#  12                                    Minority Leader
#  13                                  Opposition Leader
#  14                                          Structure
#  15                                              Seats
# ...

# %%
#cadeiras_estado = tabela[2]

# OU

page = pd.read_html(url, match='Difference')
page
#cadeiras_estado = tabela[0]
# Out:
# [          Federal state  Deputies currently allotted      %  \
#  0             São Paulo                           70  13.6%
#  1          Minas Gerais                           53  10.3%
#  2        Rio de Janeiro                           46     9%
#  3                 Bahia                           39   7.6%
#  4     Rio Grande do Sul                           31     6%
#  5                Paraná                           30   5.8%
#  6            Pernambuco                           25   4.9%
#  7                 Ceará                           22   4.3%
#  8              Maranhão                           18   3.5%
#  9                 Goiás                           17   3.3%
#  10                 Pará                           17   3.3%
#  11       Santa Catarina                           16   3.1%
#  12              Paraíba                           12   2.3%
#  13       Espírito Santo                           10   1.9%
# ...

# %%
df = page[0]
df
# Out:
#           Federal state  Deputies currently allotted      %  \
# 0             São Paulo                           70  13.6%
# 1          Minas Gerais                           53  10.3%
# 2        Rio de Janeiro                           46     9%
# 3                 Bahia                           39   7.6%
# 4     Rio Grande do Sul                           31     6%
# 5                Paraná                           30   5.8%
# 6            Pernambuco                           25   4.9%
# 7                 Ceará                           22   4.3%
# 8              Maranhão                           18   3.5%
# 9                 Goiás                           17   3.3%
# 10                 Pará                           17   3.3%
# 11       Santa Catarina                           16   3.1%
# 12              Paraíba                           12   2.3%
# 13       Espírito Santo                           10   1.9%
# 14                Piauí                           10   1.9%
# ...

# %%
df.iloc[0]
# Out:
# Federal state                         São Paulo
# Deputies currently allotted                  70
# %                                         13.6%
# Population (2010 Census)               39924091
# %.1                                       21.5%
# Population per deputy                    570344
# Deputies in proportional allotment          110
# Difference (actual−proportional)            –40
# Name: 0, dtype: object
